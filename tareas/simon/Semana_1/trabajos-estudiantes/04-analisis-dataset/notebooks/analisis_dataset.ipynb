# %% [markdown]
# # Proyecto: Indagación de un dataset
#
# Lee primero `INSTRUCCIONES.md` (en la raíz de este proyecto). Igual que en el proyecto del carrito: el notebook solo **carga datos**, **importa** funciones de análisis desde `src/app/analisis.py`, y **muestra** resultados. Toda la lógica de análisis va en el `.py`.

# %% [markdown]
# ## 0. Importa pandas y tus funciones de análisis
#
# Ya resolviste en el proyecto anterior cómo importar código que vive en `src/app/` desde un notebook que vive en `notebooks/`. Reutiliza esa misma solución aquí.

# %%
import pandas as pd

# TODO: importa el módulo analisis.py (en src/app/) — misma solución que usaste
# en el proyecto del carrito.
...

# %% [markdown]
# ## 1. Carga el dataset
#
# El archivo del dataset debe estar en la carpeta `data/` de este proyecto (no lo subas al repositorio del curso si pesa mucho — pregúntale al profesor cómo se comparte).

# %%
# TODO: reemplaza "nombre_del_archivo.csv" por el nombre real del archivo
# que pusiste en data/
df = pd.read_csv("../data/nombre_del_archivo.csv")

df.head()

# %% [markdown]
# ## 2. Corre el análisis
#
# Todo lo que sigue depende de que hayas completado las funciones en `src/app/analisis.py`. Empieza probándolas una por una, y al final júntalas con `analizar_dataframe`.

# %%
analisis.reporte_nulos(df)

# %%
analisis.reporte_tipos(df)

# %%
analisis.reporte_tendencia_central(df)

# %% [markdown]
# ### ✏️ Ahora todo junto
#
# Llama a `analisis.analizar_dataframe(df)`, que debe encadenar los tres reportes de arriba y además comparar dos columnas numéricas relacionadas del dataset (defínelo dentro de la función, según lo que tenga sentido para tus datos).

# %%
analisis.analizar_dataframe(df)

# %% [markdown]
# ## 3. Reflexión (respóndela en esta celda, en texto)
#
# - ¿Qué columnas tienen más valores faltantes? ¿Se te ocurre una razón por la que falten justo esos datos (y no otros)?
# - Mirando la media y la mediana de las columnas numéricas: ¿coinciden más o menos, o hay una diferencia grande? Si hay una diferencia grande, ¿qué te dice eso sobre los datos (piensa en la lección de la sesión 1 sobre outliers)?
# - Tu reporte muestra la moda de `Quantity` pero no la de `Price Per Unit` ni la de `Total Spent`. Explica con tus palabras por qué: ¿qué tendría de engañoso reportar "el precio más frecuente" en una columna donde casi ningún valor se repite? ¿En qué tipo de variable sí es la moda la mejor medida de tendencia central — mejor incluso que la media?
# - Si encontraste filas donde una columna no coincide con el resultado esperado de operar otras dos (por ejemplo, un total que no cuadra con cantidad × precio): ¿cómo corregirías esos datos? ¿Los eliminarías, los recalcularías, o los marcarías como sospechosos y seguirías investigando? Justifica tu respuesta.
#
# *(Escribe tu respuesta aquí, reemplazando este texto.)*
